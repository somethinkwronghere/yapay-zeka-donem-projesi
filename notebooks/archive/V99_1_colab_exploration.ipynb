# %%
# !rm -rf sample_data

# %%
# !unzip FilesV2.zip #MarketGPT.zip
# Out:
# Archive:  FilesV2.zip
#   inflating: market_engine.py
#   inflating: test.py
#   inflating: test_marketgpt.py
#   inflating: test_training.bat
#   inflating: test_training.sh
#   inflating: train_50M.bat
#   inflating: train_50M.sh
#   inflating: train_127M.bat
#   inflating: train_127M.sh
#   inflating: train_sota.bat
#   inflating: train_sota.sh
#   inflating: Visiualize.py
#    creating: market_gpt/
#   inflating: market_gpt/data_engine.py
#   inflating: market_gpt/generator.py
#   inflating: market_gpt/inference.py
#   inflating: market_gpt/model.py
#   inflating: market_gpt/requirements.txt
#   inflating: market_gpt/train.py
#   inflating: market_gpt/utils.py
#   inflating: market_gpt/__init__.py
#    creating: market_gpt/__pycache__/
#   inflating: market_gpt/__pycache__/data_engine.cpython-311.pyc
#   inflating: market_gpt/__pycache__/data_engine.cpython-312.pyc
#   inflating: market_gpt/__pycache__/generator.cpython-311.pyc
# ...

# %%
# !rm MarketGPT.zip
# Out:
# rm: cannot remove 'MarketGPT.zip': No such file or directory

# %%
# !python market_gpt/train.py \
  --csv "ham en güncel veri.csv" \
  --output ./checkpoints_large \
  --epochs 100 \
  --batch_size 128 \
  --seq_len 256 \
  --lr 1e-4 \
  --d_model 768 \
  --nhead 24 \
  --num_layers 18 \
  --dim_feedforward 3072 \
  --device cuda
# Out:
# Using device: cuda
# Loading and processing data...
# Scaler saved to checkpoints_test/market_scaler.pkl
# ✓ Data validation passed (no NaN/Inf)
#   X range: [-78.2694, 87.1752]
#   Y range: [-78.2694, 87.1752]
# Training samples: 90412
# Validation samples: 10045
# Batches per epoch: 5651
# Effective batch size: 128
# Model parameters: 56,752,138

# %%
# !python market_gpt/train.py \
  --csv "ham en güncel veri.csv" \
  --output "./checkpoints_test" \
  --epochs 1 \
  --batch_size 16 \
  --seq_len 150 \
  --lr 5e-5 \
  --d_model 512 \
  --nhead 16 \
  --num_layers 18 \
  --dim_feedforward 2048 \
  --dropout 0.2 \
  --drop_path_rate 0.3 \
  --validation_split 0.1 \
  --grad_accum_steps 8 \
  --warmup_epochs 1 \
  --early_stopping 999 \
  --device cuda
# Out:
# Using device: cuda
# Loading and processing data...
# Scaler saved to checkpoints_test/market_scaler.pkl
# ✓ Data validation passed (no NaN/Inf)
#   X range: [-78.2694, 87.1752]
#   Y range: [-78.2694, 87.1752]
# Training samples: 90412
# Validation samples: 10045
# Batches per epoch: 5651
# Effective batch size: 128
# Model parameters: 56,752,138
# Mixed Precision (AMP): Enabled
#
# ...
# Starting training with SOTA features...
# ...
#
# Epoch 1/1:   0% 7/5651 [00:01<12:54,  7.28it/s, loss=16.5104, lr=0.00e+00]/usr/local/lib/python3.12/dist-packages/torch/optim/lr_scheduler.py:192: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn(
# ...

# %%
# !python market_gpt/train.py \
  --csv "ham en güncel veri.csv" \
  --output "./checkpoints_50M" \
  --epochs 300 \
  --batch_size 16 \
  --seq_len 150 \
  --lr 5e-5 \
  --d_model 512 \
  --nhead 16 \
  --num_layers 18 \
  --dim_feedforward 2048 \
  --dropout 0.2 \
  --drop_path_rate 0.3 \
  --validation_split 0.1 \
  --grad_accum_steps 8 \
  --warmup_epochs 10 \
  --early_stopping 30 \
  --device cuda
# Out:
# Using device: cuda
# Loading and processing data...
# Scaler saved to checkpoints_50M/market_scaler.pkl
# ✓ Data validation passed (no NaN/Inf)
#   X range: [-78.2694, 87.1752]
#   Y range: [-78.2694, 87.1752]
# Training samples: 90412
# Validation samples: 10045
# Batches per epoch: 5651
# Effective batch size: 128
# Model parameters: 56,752,138
# Mixed Precision (AMP): Enabled
#
# ...
# Starting training with SOTA features...
# ...
#
# Epoch 1/300:   0% 5/5651 [00:00<10:37,  8.86it/s, loss=90.4141, lr=0.00e+00]/usr/local/lib/python3.12/dist-packages/torch/optim/lr_scheduler.py:192: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn(
# ...

# %%
# !python market_gpt/train.py --csv "ham en güncel veri.csv" --epochs 300 --output ./checkpoints
# Out:
# Using device: cuda
# Loading and processing data...
# Scaler saved to checkpoints/market_scaler.pkl
# Training samples: 100457
# Batches per epoch: 1570
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# Model parameters: 1,192,462
#
# ...
# Starting training...
# ...
#
# Epoch 1/300: 100% 1570/1570 [01:37<00:00, 16.10it/s, loss=0.3003, lr=1.00e-04]
# Epoch 1/300 - Avg Loss: 3153.8310
#   → New best model saved (loss: 3153.8310)
# Epoch 2/300: 100% 1570/1570 [01:41<00:00, 15.49it/s, loss=-0.1780, lr=9.76e-05]
# Epoch 2/300 - Avg Loss: -0.0571
#   → New best model saved (loss: -0.0571)
# Epoch 3/300: 100% 1570/1570 [01:41<00:00, 15.47it/s, loss=-0.2775, lr=9.05e-05]
# Epoch 3/300 - Avg Loss: -0.2658
#   → New best model saved (loss: -0.2658)
# Epoch 4/300: 100% 1570/1570 [01:41<00:00, 15.50it/s, loss=-0.3814, lr=7.94e-05]
# ...

# %%
# !python test_marketgpt.py
# Out:
# Loading model...
# Device: cuda
# ✓ Model loaded
# ✓ Scaler loaded
# ✓ Loaded last 300 candles
#   From: 2025-12-16 20:00:00
#   To:   2026-01-06 07:00:00
#   Last close: 1.17286
#
# Initializing generator...
# Generator initialized with 299 candles
# Last candle: {'time': Timestamp('2026-01-06 07:00:00'), 'open': 1.17336, 'high': 1.17369, 'low': 1.17271, 'close': 1.17286, 'tick_volume': 1446, 'spread': 0, 'real_volume': 0}
# ✓ Generator initialized with seed=123
#
# Generating 7000 candles...
# ✓ Generated 7000 candles
#   From: 2026-01-06 08:00:00
#   To:   2026-10-24 23:00:00
#   Final close: 1.43984
#
# Plotting TradingView-style chart...
# Figure(1600x800)
# ✓ Chart saved as 'marketgpt_simulation.png'
#
# ...
# GENERATION STATISTICS
# ...
#
# Real (Last 50):
#   Mean Return:     -0.0047%
#   Volatility:      0.0675%
#   Min:             -0.1139%
#   Max:             0.1874%
#   Price Range:     1.16589 - 1.17646
#
# Generated:
#   Mean Return:     0.0029%
#   Volatility:      0.4426%
# ...

# %%
# !zip -r files.zip ./*
# Out:
#   adding: checkpoints/ (stored 0%)
#   adding: checkpoints/market_model_epoch30.pt (deflated 8%)
#   adding: checkpoints/market_model_epoch230.pt (deflated 7%)
#   adding: checkpoints/market_model_epoch260.pt (deflated 7%)
#   adding: checkpoints/market_model_epoch250.pt (deflated 7%)
#   adding: checkpoints/market_model_epoch20.pt (deflated 7%)
#   adding: checkpoints/market_model_epoch170.pt (deflated 7%)
#   adding: checkpoints/market_model_best.pt (deflated 7%)
#   adding: checkpoints/market_model_epoch40.pt (deflated 7%)
#   adding: checkpoints/market_model_epoch90.pt (deflated 7%)
#   adding: checkpoints/market_model_epoch200.pt (deflated 7%)
#   adding: checkpoints/market_scaler.pkl (deflated 33%)
#   adding: checkpoints/market_model_epoch60.pt (deflated 7%)
#   adding: checkpoints/training_history.json (deflated 77%)
#   adding: checkpoints/market_model_epoch280.pt (deflated 7%)
#   adding: checkpoints/market_model_epoch220.pt (deflated 7%)
# ...

# %%
# ✅ Telegram Bot Parameters
TOKEN = "7680999779:AAGdapYsS3Uh7VsWI62vMhlaadMKM6rkWO8"
chat_id = "1071315137"

# %%
# !pip install "python_telegram_bot==12.4.2"
# !pip install urllib3==1.26.15
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.9/360.9 kB 12.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.9/140.9 kB 9.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
# ...

# %%
import requests
# Detaylı rapor mesajı
message = ("*✅ Eğitim Tamamlandı*\n")

url = f"https://api.telegram.org/bot{TOKEN}/sendMessage"
params = {
    "chat_id": chat_id,
    "text": message,
    "parse_mode": "Markdown"
}
response = requests.get(url, params=params)
print(response.json())
# Out:
# {'ok': True, 'result': {'message_id': 309, 'from': {'id': 7680999779, 'is_bot': True, 'first_name': 'Felterflack Bot', 'username': 'Felterflack_bot'}, 'chat': {'id': 1071315137, 'first_name': 'Cenk', 'last_name': 'Karatopcu', 'username': 'cenkkaratopcu', 'type': 'private'}, 'date': 1769569291, 'text': '✅ Eğitim Tamamlandı', 'entities': [{'offset': 0, 'length': 19, 'type': 'bold'}]}}

# %%
# !mv checkpoints/market_model_final.pt /

# %%
# !python market_gpt/train.py \
  --csv "ham en güncel veri.csv" \
  --output "./checkpoints_50M" \
  --epochs 300 \
  --batch_size 16 \
  --seq_len 150 \
  --lr 5e-5 \
  --d_model 512 \
  --nhead 16 \
  --num_layers 18 \
  --dim_feedforward 2048 \
  --dropout 0.2 \
  --drop_path_rate 0.3 \
  --validation_split 0.1 \
  --grad_accum_steps 8 \
  --warmup_epochs 10 \
  --early_stopping 30 \
  --device cuda
# Out:
# Using device: cuda
# Loading and processing data...
# Scaler saved to checkpoints_50M/market_scaler.pkl
# ✓ Data validation passed (no NaN/Inf)
#   X range: [-78.2694, 87.1752]
#   Y range: [-78.2694, 87.1752]
# Training samples: 90412
# Validation samples: 10045
# Batches per epoch: 5651
# Effective batch size: 128
# Model parameters: 56,752,138
# Mixed Precision (AMP): Enabled
#
# ...
# Starting training with SOTA features...
# ...
#
# Epoch 1/300:   0% 7/5651 [00:01<12:27,  7.55it/s, loss=31.9914, lr=0.00e+00]/usr/local/lib/python3.12/dist-packages/torch/optim/lr_scheduler.py:192: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn(
# ...

# %%
# !python market_gpt/train.py \
  --csv "ham en güncel veri.csv" \
  --output "./checkpoints_50M" \
  --epochs 300 \
  --batch_size 16 \
  --seq_len 150 \
  --lr 1e-5 \
  --d_model 512 \
  --nhead 16 \
  --num_layers 18 \
  --dim_feedforward 2048 \
  --dropout 0.4 \
  --drop_path_rate 0.4 \
  --validation_split 0.1 \
  --grad_accum_steps 8 \
  --warmup_epochs 10 \
  --early_stopping 40 \
  --device cuda
# Out:
# Using device: cuda
# Loading and processing data...
# Scaler saved to checkpoints_50M/market_scaler.pkl
# ✓ Data validation passed (no NaN/Inf)
#   X range: [-78.2694, 87.1752]
#   Y range: [-78.2694, 87.1752]
# Training samples: 90412
# Validation samples: 10045
# Batches per epoch: 5651
# Effective batch size: 128
# Model parameters: 56,752,138
# Mixed Precision (AMP): Enabled
#
# ...
# Starting training with SOTA features...
# ...
#
# Epoch 1/300: 100% 5651/5651 [04:45<00:00, 19.79it/s, loss=1.3062, lr=1.00e-06]
# Epoch 1/300 - Train Loss: 3.9429 | Val Loss: 1.7214 | LR: 1.00e-06
#   → ✓ New best model saved (val_loss: 1.7214)
# Epoch 2/300: 100% 5651/5651 [04:41<00:00, 20.09it/s, loss=0.7746, lr=2.00e-06]
# Epoch 2/300 - Train Loss: 1.0861 | Val Loss: 0.6846 | LR: 2.00e-06
#   → ✓ New best model saved (val_loss: 0.6846)
# Epoch 3/300: 100% 5651/5651 [04:42<00:00, 20.01it/s, loss=0.5990, lr=3.00e-06]
# Epoch 3/300 - Train Loss: 0.7392 | Val Loss: 0.4579 | LR: 3.00e-06
# ...

# %%
# !python market_gpt/train.py \
  --csv "ham en güncel veri.csv" \
  --output "./checkpoints_50M" \
  --epochs 300 \
  --batch_size 16 \
  --seq_len 150 \
  --lr 1e-5 \
  --d_model 512 \
  --nhead 16 \
  --num_layers 18 \
  --dim_feedforward 2048 \
  --dropout 0.4 \
  --drop_path_rate 0.4 \
  --validation_split 0.1 \
  --grad_accum_steps 8 \
  --warmup_epochs 10 \
  --early_stopping 40 \
  --device cuda
# Out:
# Using device: cuda
# Loading and processing data...
# Scaler saved to checkpoints_50M/market_scaler.pkl
# ✓ Data validation passed (no NaN/Inf)
#   X range: [-78.2694, 87.1752]
#   Y range: [-78.2694, 87.1752]
# Training samples: 90412
# Validation samples: 10045
# Batches per epoch: 5651
# Effective batch size: 128
# Model parameters: 56,752,138
# Mixed Precision (AMP): Enabled
#
# ...
# Starting training with SOTA features...
# ...
#
# Epoch 1/300:   0% 7/5651 [00:00<08:19, 11.30it/s, loss=26.8628, lr=0.00e+00]/usr/local/lib/python3.12/dist-packages/torch/optim/lr_scheduler.py:192: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn(
# ...

# %%
# !python market_gpt/train.py \
  --csv "ham en güncel veri.csv" \
  --output "./checkpoints_50M" \
  --epochs 300 \
  --batch_size 16 \
  --seq_len 150 \
  --lr 1e-5 \
  --d_model 512 \
  --nhead 16 \
  --num_layers 18 \
  --dim_feedforward 2048 \
  --dropout 0.4 \
  --drop_path_rate 0.4 \
  --validation_split 0.1 \
  --grad_accum_steps 8 \
  --warmup_epochs 10 \
  --early_stopping 40 \
  --device cuda
# Out:
# Using device: cuda
# Loading and processing data...
# Scaler saved to checkpoints_50M/market_scaler.pkl
# ✓ Data validation passed (no NaN/Inf)
#   X range: [-5.0000, 5.0000]
#   Y range: [-5.0000, 5.0000]
# Training samples: 90412
# Validation samples: 10045
# Batches per epoch: 5651
# Effective batch size: 128
# Model parameters: 56,752,138
# Mixed Precision (AMP): Enabled
#
# ...
# Starting training with SOTA features...
# ...
#
# Epoch 1/300:   0% 5/5651 [00:00<10:47,  8.71it/s, loss=51.1766, lr=0.00e+00]/usr/local/lib/python3.12/dist-packages/torch/optim/lr_scheduler.py:192: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn(
# ...

# %%
# !python market_gpt/train.py \
  --csv "ham en güncel veri.csv" \
  --output "./checkpoints_50M" \
  --epochs 300 \
  --batch_size 16 \
  --seq_len 150 \
  --lr 1e-5 \
  --d_model 512 \
  --nhead 16 \
  --num_layers 18 \
  --dim_feedforward 2048 \
  --dropout 0.4 \
  --drop_path_rate 0.4 \
  --validation_split 0.1 \
  --grad_accum_steps 8 \
  --warmup_epochs 10 \
  --early_stopping 40 \
  --device cuda
# Out:
# Using device: cuda
# Loading and processing data...
# Scaler saved to checkpoints_50M/market_scaler.pkl
# ✓ Data validation passed (no NaN/Inf)
#   X range: [-78.2694, 87.1752]
#   Y range: [-78.2694, 87.1752]
# Training samples: 90412
# Validation samples: 10045
# Batches per epoch: 5651
# Effective batch size: 128
# Model parameters: 56,752,138
# Mixed Precision (AMP): Enabled
#
# ...
# Starting training with SOTA features...
# ...
#
# Epoch 1/300:   0% 6/5651 [00:01<14:20,  6.56it/s, loss=45.7995, lr=0.00e+00]/content/market_gpt/train.py:243: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   scheduler.step()
# ...

# %%
import requests
TOKEN = "7680999779:AAGdapYsS3Uh7VsWI62vMhlaadMKM6rkWO8"
chat_id = "1071315137"
message = "="*15
message += "\nİşlem Bitti\n"
message += "="*15
url = f"https://api.telegram.org/bot{TOKEN}/sendMessage?chat_id={chat_id}&text={message}"
print(requests.get(url).json())
# Out:
# {'ok': True, 'result': {'message_id': 311, 'from': {'id': 7680999779, 'is_bot': True, 'first_name': 'Felterflack Bot', 'username': 'Felterflack_bot'}, 'chat': {'id': 1071315137, 'first_name': 'Cenk', 'last_name': 'Karatopcu', 'username': 'cenkkaratopcu', 'type': 'private'}, 'date': 1772628398, 'text': '===============\nİşlem Bitti\n==============='}}

# %%
# !zip -r ./3_04_2026.zip ./checkpoints_50M/
# Out:
#   adding: checkpoints_50M/ (stored 0%)
#   adding: checkpoints_50M/market_model_epoch20.pt (deflated 7%)
#   adding: checkpoints_50M/market_model_epoch30.pt (deflated 7%)
#   adding: checkpoints_50M/market_model_final.pt (deflated 8%)
#   adding: checkpoints_50M/market_model_epoch70.pt (deflated 7%)
#   adding: checkpoints_50M/market_model_epoch80.pt (deflated 7%)
#   adding: checkpoints_50M/market_model_epoch40.pt (deflated 7%)
#   adding: checkpoints_50M/market_model_best.pt (deflated 7%)
#   adding: checkpoints_50M/training_config.json (deflated 44%)
#   adding: checkpoints_50M/market_model_epoch50.pt (deflated 7%)
#   adding: checkpoints_50M/market_scaler.pkl (deflated 36%)
#   adding: checkpoints_50M/market_model_epoch60.pt (deflated 7%)
#   adding: checkpoints_50M/training_history.json (deflated 73%)
#   adding: checkpoints_50M/market_model_epoch10.pt (deflated 8%)

# %%
import requests
TOKEN = "7680999779:AAGdapYsS3Uh7VsWI62vMhlaadMKM6rkWO8"
chat_id = "1071315137"
message = "="*15
message += "\nİşlem Bitti\n"
message += "="*15
url = f"https://api.telegram.org/bot{TOKEN}/sendMessage?chat_id={chat_id}&text={message}"
print(requests.get(url).json())
# Out:
# {'ok': True, 'result': {'message_id': 313, 'from': {'id': 7680999779, 'is_bot': True, 'first_name': 'Felterflack Bot', 'username': 'Felterflack_bot'}, 'chat': {'id': 1071315137, 'first_name': 'Cenk', 'last_name': 'Karatopcu', 'username': 'cenkkaratopcu', 'type': 'private'}, 'date': 1772631077, 'text': '===============\nİşlem Bitti\n==============='}}
